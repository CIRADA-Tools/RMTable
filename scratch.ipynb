# %%
from astropy.table import Table

# %%
ucds = Table.read('ucd1p-words.txt', format='ascii.no_header').to_pandas()
ucds
# Out:
#     col1             col2                                               col3
# 0      Q            arith                              Arithmetic quantities
# 1      S       arith.diff  Difference between two quantities described by...
# 2      P     arith.factor                                   Numerical factor
# 3      P       arith.grad                                           Gradient
# 4      P       arith.rate                               Rate (per time unit)
# ..   ...              ...                                                ...
# 518    Q       time.relax                                    Relaxation time
# 519    Q     time.release      The time/date data is available to the public
# 520    Q  time.resolution                                    Time resolution
# 521    Q       time.scale                                          Timescale
# 522    Q       time.start                   Start time/date of generic event
#
# [523 rows x 3 columns]

# %%
import rmtable as rmt
import numpy as np

# %%
standard=[  
    ['ra','f8',[0,360],None,'deg'],
    ['dec','f8',[-90,90],None,'deg'],
    ['l','f8',[0,360],None,'deg'],
    ['b','f8',[-90,90],None,'deg'],
    ['pos_err','f4',[0,np.inf],np.nan,'deg'],
    ['rm','f4',[-np.inf,np.inf],np.nan,'rad.m-2'],
    ['rm_err','f4',[0,np.inf],np.nan,'rad.m-2'],
    ['rm_width','f4',[0,np.inf],np.nan,'rad.m-2'],
    ['rm_width_err','f4',[0,np.inf],np.nan,'rad.m-2'],
    ['complex_flag','U1','','U','',],
    ['complex_test','U80','','','',],
    ['rm_method','U40','','Unknown','',],
    ['ionosphere','U40','','Unknown',''],
    ['Ncomp','i4',[1,np.inf],1,''],
    ['stokesI','f4',[0,np.inf],np.nan,'Jy'],
    ['stokesI_err','f4',[0,np.inf],np.nan,'Jy'],
    ['spectral_index','f4',[-np.inf,np.inf],np.nan,''],
    ['spectral_index_err','f4',[0,np.inf],np.nan,''],
    ['reffreq_I','f4',[-np.inf,np.inf],np.nan,'Hz'],
    ['polint','f4',[0,np.inf],np.nan,'Jy'],
    ['polint_err','f4',[0,np.inf],np.nan,'Jy'],
    ['pol_bias','U40','','Unknown',''],
    ['flux_type','U40','','Unknown',''],
    ['aperture','f4',[0,np.inf],np.nan,'deg'],
    ['fracpol','f4',[0,np.inf],np.nan,''],
    ['fracpol_err','f4',[0,np.inf],np.nan,''],
    ['polangle','f4',[0,180],np.nan,'deg'],
    ['polangle_err','f4',[0,np.inf],np.nan,'deg'],
    ['reffreq_pol','f4',[0,np.inf],np.nan,'Hz'],
    ['stokesQ','f4',[-np.inf,np.inf],np.nan,'Jy'],
    ['stokesQ_err','f4',[0,np.inf],np.nan,'Jy'],
    ['stokesU','f4',[-np.inf,np.inf],np.nan,'Jy'],
    ['stokesU_err','f4',[0,np.inf],np.nan,'Jy'],
    ['derot_polangle','f4',[0,180],np.nan,'deg'],
    ['derot_polangle_err','f4',[0,np.inf],np.nan,'deg'],
    ['stokesV','f4',[-np.inf,np.inf],np.nan,'Jy'],
    ['stokesV_err','f4',[0,np.inf],np.nan,'Jy'],
    ['beam_maj','f4',[0,np.inf],np.nan,'deg'],
    ['beam_min','f4',[0,np.inf],np.nan,'deg'],
    ['beam_pa','f4',[0,180],np.nan,'deg'],
    ['reffreq_beam','f4',[0,np.inf],np.nan,'Hz'],
    ['minfreq','f4',[0,np.inf],np.nan,'Hz'],
    ['maxfreq','f4',[0,np.inf],np.nan,'Hz'],
    ['channelwidth','f4',[0,np.inf],np.nan,'Hz'],
    ['Nchan','i4',[0,np.inf],-2147483648,''],
    ['rmsf_fwhm','f4',[0,np.inf],np.nan,'rad.m-2'],
    ['noise_chan','f4',[0,np.inf],np.nan,'Jy'],
    ['telescope','U80','','Unknown',''],
    ['int_time','f4',[0,np.inf],np.nan,'s'],
    ['epoch','f4',[-np.inf,np.inf],np.nan,'day'],
    ['interval','f4',[0,np.inf],np.nan,'day'],
    ['leakage','f4',[0,np.inf],np.nan,''],
    ['beamdist','f4',[0,np.inf],np.nan,'deg'],
    ['catalog','U40','',None,''],
    ['dataref','U400','','',''],
    ['cat_id','U40','','',''],
    ['type','U40','','',''],
    ['notes','U200','','','']        ]

# %%
import numpy as np
import json
import yaml

# %%
standard_dict = {}
for s in standard:
    standard_dict[s[0]] = {
        "dtype":s[1],
        "limits":s[2],
        "blank":s[3],
        "units":s[4]
    }
version = "1.2"
standard_dict["version"] = version

# %%
rmt.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/rg/tk14ndkj435d8d1yj25dbz1w00p7kq/T/ipykernel_60942/1858738064.py in <module>
# ----> 1 rmt.__version__
#
# AttributeError: module 'rmtable' has no attribute '__version__'

# %%
with open(f'standard_dict_v{version}.json', 'w') as f:
    json.dump(standard_dict, f)
with open(f'standard_dict_v{version}.json', 'r') as f:
    test = json.load(f)
test
# Out:
# {'ra': {'dtype': 'f8', 'limits': [0, 360], 'blank': None, 'units': 'deg'},
#  'dec': {'dtype': 'f8', 'limits': [-90, 90], 'blank': None, 'units': 'deg'},
#  'l': {'dtype': 'f8', 'limits': [0, 360], 'blank': None, 'units': 'deg'},
#  'b': {'dtype': 'f8', 'limits': [-90, 90], 'blank': None, 'units': 'deg'},
#  'pos_err': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'rm': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'rm_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'rm_width': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'rm_width_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'complex_flag': {'dtype': 'U1', 'limits': '', 'blank': 'U', 'units': ''},
#  'complex_test': {'dtype': 'U80', 'limits': '', 'blank': '', 'units': ''},
#  'rm_method': {'dtype': 'U40', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'ionosphere': {'dtype': 'U40', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'Ncomp': {'dtype': 'i4', 'limits': [1, inf], 'blank': 1, 'units': ''},
#  'stokesI': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'Jy'},
#  'stokesI_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'spectral_index': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': ''},
#  'spectral_index_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': ''},
#  'reffreq_I': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'Hz'},
#  'polint': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'Jy'},
#  'polint_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'pol_bias': {'dtype': 'U40', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'flux_type': {'dtype': 'U40', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'aperture': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'fracpol': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': ''},
#  'fracpol_err': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': ''},
#  'polangle': {'dtype': 'f4', 'limits': [0, 180], 'blank': nan, 'units': 'deg'},
#  'polangle_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'deg'},
#  'reffreq_pol': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Hz'},
#  'stokesQ': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'stokesQ_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'stokesU': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'stokesU_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'derot_polangle': {'dtype': 'f4',
#   'limits': [0, 180],
#   'blank': nan,
#   'units': 'deg'},
#  'derot_polangle_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'deg'},
#  'stokesV': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'stokesV_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'beam_maj': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'beam_min': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'beam_pa': {'dtype': 'f4', 'limits': [0, 180], 'blank': nan, 'units': 'deg'},
#  'reffreq_beam': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Hz'},
#  'minfreq': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'Hz'},
#  'maxfreq': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'Hz'},
#  'channelwidth': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Hz'},
#  'Nchan': {'dtype': 'i4',
#   'limits': [0, inf],
#   'blank': -2147483648,
#   'units': ''},
#  'rmsf_fwhm': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'noise_chan': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'telescope': {'dtype': 'U80', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'int_time': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 's'},
#  'epoch': {'dtype': 'f4', 'limits': [-inf, inf], 'blank': nan, 'units': 'day'},
#  'interval': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'day'},
#  'leakage': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': ''},
#  'beamdist': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'catalog': {'dtype': 'U40', 'limits': '', 'blank': None, 'units': ''},
#  'dataref': {'dtype': 'U400', 'limits': '', 'blank': '', 'units': ''},
#  'cat_id': {'dtype': 'U40', 'limits': '', 'blank': '', 'units': ''},
#  'type': {'dtype': 'U40', 'limits': '', 'blank': '', 'units': ''},
#  'notes': {'dtype': 'U200', 'limits': '', 'blank': '', 'units': ''},
#  'version': '1.2'}

# %%
# Out:
# {'ra': {'dtype': 'f8', 'limits': [0, 360], 'blank': None, 'units': 'deg'},
#  'dec': {'dtype': 'f8', 'limits': [-90, 90], 'blank': None, 'units': 'deg'},
#  'l': {'dtype': 'f8', 'limits': [0, 360], 'blank': None, 'units': 'deg'},
#  'b': {'dtype': 'f8', 'limits': [-90, 90], 'blank': None, 'units': 'deg'},
#  'pos_err': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'rm': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'rm_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'rm_width': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'rm_width_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'complex_flag': {'dtype': 'U1', 'limits': '', 'blank': 'U', 'units': ''},
#  'complex_test': {'dtype': 'U80', 'limits': '', 'blank': '', 'units': ''},
#  'rm_method': {'dtype': 'U40', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'ionosphere': {'dtype': 'U40', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'Ncomp': {'dtype': 'i4', 'limits': [1, inf], 'blank': 1, 'units': ''},
#  'stokesI': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'Jy'},
#  'stokesI_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'spectral_index': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': ''},
#  'spectral_index_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': ''},
#  'reffreq_I': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'Hz'},
#  'polint': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'Jy'},
#  'polint_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'pol_bias': {'dtype': 'U40', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'flux_type': {'dtype': 'U40', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'aperture': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'fracpol': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': ''},
#  'fracpol_err': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': ''},
#  'polangle': {'dtype': 'f4', 'limits': [0, 180], 'blank': nan, 'units': 'deg'},
#  'polangle_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'deg'},
#  'reffreq_pol': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Hz'},
#  'stokesQ': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'stokesQ_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'stokesU': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'stokesU_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'derot_polangle': {'dtype': 'f4',
#   'limits': [0, 180],
#   'blank': nan,
#   'units': 'deg'},
#  'derot_polangle_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'deg'},
#  'stokesV': {'dtype': 'f4',
#   'limits': [-inf, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'stokesV_err': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'beam_maj': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'beam_min': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'beam_pa': {'dtype': 'f4', 'limits': [0, 180], 'blank': nan, 'units': 'deg'},
#  'reffreq_beam': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Hz'},
#  'minfreq': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'Hz'},
#  'maxfreq': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'Hz'},
#  'channelwidth': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Hz'},
#  'Nchan': {'dtype': 'i4',
#   'limits': [0, inf],
#   'blank': -2147483648,
#   'units': ''},
#  'rmsf_fwhm': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'rad.m-2'},
#  'noise_chan': {'dtype': 'f4',
#   'limits': [0, inf],
#   'blank': nan,
#   'units': 'Jy'},
#  'telescope': {'dtype': 'U80', 'limits': '', 'blank': 'Unknown', 'units': ''},
#  'int_time': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 's'},
#  'epoch': {'dtype': 'f4', 'limits': [-inf, inf], 'blank': nan, 'units': 'day'},
#  'interval': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'day'},
#  'leakage': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': ''},
#  'beamdist': {'dtype': 'f4', 'limits': [0, inf], 'blank': nan, 'units': 'deg'},
#  'catalog': {'dtype': 'U40', 'limits': '', 'blank': None, 'units': ''},
#  'dataref': {'dtype': 'U400', 'limits': '', 'blank': '', 'units': ''},
#  'cat_id': {'dtype': 'U40', 'limits': '', 'blank': '', 'units': ''},
#  'type': {'dtype': 'U40', 'limits': '', 'blank': '', 'units': ''},
#  'notes': {'dtype': 'U200', 'limits': '', 'blank': '', 'units': ''},
#  'version': '1.2'}

# %%
with open('standard_dict.yaml', 'w') as f:
    yaml.dump(standard_dict, f)

# %%
with open('standard_dict.yaml', 'r') as f:
    test = yaml.load(f)
test
# Out:
# /var/folders/rg/tk14ndkj435d8d1yj25dbz1w00p7kq/T/ipykernel_60942/4053563722.py:2: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   test = yaml.load(f)
# {'Nchan': {'blank': -2147483648,
#   'dtype': 'i4',
#   'limits': [0, inf],
#   'units': ''},
#  'Ncomp': {'blank': 1, 'dtype': 'i4', 'limits': [1, inf], 'units': ''},
#  'aperture': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'deg'},
#  'b': {'blank': None, 'dtype': 'f8', 'limits': [-90, 90], 'units': 'deg'},
#  'beam_maj': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'deg'},
#  'beam_min': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'deg'},
#  'beam_pa': {'blank': nan, 'dtype': 'f4', 'limits': [0, 180], 'units': 'deg'},
#  'beamdist': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'deg'},
#  'cat_id': {'blank': '', 'dtype': 'U40', 'limits': '', 'units': ''},
#  'catalog': {'blank': None, 'dtype': 'U40', 'limits': '', 'units': ''},
#  'channelwidth': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Hz'},
#  'complex_flag': {'blank': 'U', 'dtype': 'U1', 'limits': '', 'units': ''},
#  'complex_test': {'blank': '', 'dtype': 'U80', 'limits': '', 'units': ''},
#  'dataref': {'blank': '', 'dtype': 'U400', 'limits': '', 'units': ''},
#  'dec': {'blank': None, 'dtype': 'f8', 'limits': [-90, 90], 'units': 'deg'},
#  'derot_polangle': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, 180],
#   'units': 'deg'},
#  'derot_polangle_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'deg'},
#  'epoch': {'blank': nan, 'dtype': 'f4', 'limits': [-inf, inf], 'units': 'day'},
#  'flux_type': {'blank': 'Unknown', 'dtype': 'U40', 'limits': '', 'units': ''},
#  'fracpol': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': ''},
#  'fracpol_err': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': ''},
#  'int_time': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 's'},
#  'interval': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'day'},
#  'ionosphere': {'blank': 'Unknown', 'dtype': 'U40', 'limits': '', 'units': ''},
#  'l': {'blank': None, 'dtype': 'f8', 'limits': [0, 360], 'units': 'deg'},
#  'leakage': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': ''},
#  'maxfreq': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'Hz'},
#  'minfreq': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'Hz'},
#  'noise_chan': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Jy'},
#  'notes': {'blank': '', 'dtype': 'U200', 'limits': '', 'units': ''},
#  'pol_bias': {'blank': 'Unknown', 'dtype': 'U40', 'limits': '', 'units': ''},
#  'polangle': {'blank': nan, 'dtype': 'f4', 'limits': [0, 180], 'units': 'deg'},
#  'polangle_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'deg'},
#  'polint': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'Jy'},
#  'polint_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Jy'},
#  'pos_err': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'deg'},
#  'ra': {'blank': None, 'dtype': 'f8', 'limits': [0, 360], 'units': 'deg'},
#  'reffreq_I': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [-inf, inf],
#   'units': 'Hz'},
#  'reffreq_beam': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Hz'},
#  'reffreq_pol': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Hz'},
#  'rm': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [-inf, inf],
#   'units': 'rad.m-2'},
#  'rm_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'rad.m-2'},
#  'rm_method': {'blank': 'Unknown', 'dtype': 'U40', 'limits': '', 'units': ''},
#  'rm_width': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'rad.m-2'},
#  'rm_width_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'rad.m-2'},
#  'rmsf_fwhm': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'rad.m-2'},
#  'spectral_index': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [-inf, inf],
#   'units': ''},
#  'spectral_index_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': ''},
#  'stokesI': {'blank': nan, 'dtype': 'f4', 'limits': [0, inf], 'units': 'Jy'},
#  'stokesI_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Jy'},
#  'stokesQ': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [-inf, inf],
#   'units': 'Jy'},
#  'stokesQ_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Jy'},
#  'stokesU': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [-inf, inf],
#   'units': 'Jy'},
#  'stokesU_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Jy'},
#  'stokesV': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [-inf, inf],
#   'units': 'Jy'},
#  'stokesV_err': {'blank': nan,
#   'dtype': 'f4',
#   'limits': [0, inf],
#   'units': 'Jy'},
#  'telescope': {'blank': 'Unknown', 'dtype': 'U80', 'limits': '', 'units': ''},
#  'type': {'blank': '', 'dtype': 'U40', 'limits': '', 'units': ''}}
